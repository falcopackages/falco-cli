# %%
from dj_notebook import activate

plus = activate()

# %%
from django.core.management import call_command
from {{ cookiecutter.project_name }}.core.management.commands import makesuperuser

call_command(makesuperuser.Command())
